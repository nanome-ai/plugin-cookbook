# %%
import websocket
import os
import json
ws_url = os.environ.get("WEBSOCKET_SERVER")
print(ws_url)
ws = websocket.WebSocket()
ws.connect(ws_url)
ws.send(json.dumps({"type":"host", "data":"World"}))
print(ws.recv())
ws.close()
# Out:
# ws://websocket_server
# WebSocketConnectionClosedExceptionTraceback (most recent call last)
# Input In [6], in <cell line: 9>()
#       7 ws.connect(ws_url)
#       8 ws.send(json.dumps({"type":"host", "data":"World"}))
# ----> 9 print(ws.recv())
#      10 ws.close()
#
# File /opt/conda/lib/python3.9/site-packages/websocket/_core.py:362, in WebSocket.recv(self)
#     354 """
#     355 Receive string data(byte array) from the server.
#     356
#    (...)
#     359 data: string (byte array) value.
#     360 """
#     361 with self.readlock:
# --> 362     opcode, data = self.recv_data()
#     363 if opcode == ABNF.OPCODE_TEXT:
#     364     return data.decode("utf-8")
#
# File /opt/conda/lib/python3.9/site-packages/websocket/_core.py:385, in WebSocket.recv_data(self, control_frame)
#     370 def recv_data(self, control_frame=False):
#     371     """
#     372     Receive data with operation code.
#     373
#    (...)
# ...
